# %%
import cv2
import torch
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %%
torch.backends.cudnn.enabled = False

# %%
torch.cuda.empty_cache()

# %%
model = YOLO('yolov8s.pt')
model.train(data='../custom.yaml', epochs=30, imgsz=640, batch=-1, plots=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
# 100%|██████████| 21.5M/21.5M [00:18<00:00, 1.20MB/s]
# Ultralytics YOLOv8.0.42  Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# yolo\engine\trainer: task=detect, mode=train, model=yolov8s.pt, data=../custom.yaml, epochs=30, patience=50, batch=-1, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, min_memory=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, split=val, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# AutoBatch: Computing optimal batch size for imgsz=640
# AutoBatch: CUDA:0 (NVIDIA GeForce GTX 1650 Ti) 4.00G total, 0.09G reserved, 0.08G allocated, 3.83G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     11135987       28.65         0.409         104.2         100.7        (1, 3, 640, 640)                    list
#     11135987       57.29         0.602           185         192.9        (2, 3, 640, 640)                    list
#     11135987       114.6         1.057         367.9         385.6        (4, 3, 640, 640)                    list
#     11135987       229.2         1.919         813.5         935.2        (8, 3, 640, 640)                    list
#     11135987       458.4         3.643          1757          2338       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 11 for CUDA:0 2.74G/4.00G (68%)
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.00103125), 63 bias
# train: Scanning F:\TruckDetect\Yolov8_Module\TruckDataset\train\labels... 592 images, 28 backgrounds, 0 corrupt: 100%|██████████| 620/620 [00:03<00:00, 199.65it/s]
# train: New cache created: F:\TruckDetect\Yolov8_Module\TruckDataset\train\labels.cache
# val: Scanning F:\TruckDetect\Yolov8_Module\TruckDataset\valid\labels... 148 images, 6 backgrounds, 0 corrupt: 100%|██████████| 154/154 [00:00<00:00, 184.28it/s]
# val: New cache created: F:\TruckDetect\Yolov8_Module\TruckDataset\valid\labels.cache
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.87G      1.273      2.635      1.281         11        640: 100%|██████████| 57/57 [03:34<00:00,  3.76s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:36<00:00,  5.27s/it]
#                    all        154        249      0.594      0.438      0.463      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      3.13G     0.8995     0.9937      1.042         15        640: 100%|██████████| 57/57 [03:31<00:00,  3.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:36<00:00,  5.25s/it]
#                    all        154        249      0.917       0.58      0.723      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      3.13G     0.8701     0.9105      1.013         13        640: 100%|██████████| 57/57 [03:30<00:00,  3.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:37<00:00,  5.31s/it]
#                    all        154        249      0.825      0.594      0.669      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      3.13G      0.891     0.9003     0.9725         10        640: 100%|██████████| 57/57 [03:19<00:00,  3.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:26<00:00,  3.81s/it]
#                    all        154        249      0.938       0.85      0.902      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      3.13G     0.8941     0.8453      1.001         18        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:26<00:00,  3.77s/it]
#                    all        154        249      0.891      0.588      0.714      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      3.13G     0.8558     0.6972     0.9895          9        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.02s/it]
#                    all        154        249      0.932       0.72      0.854      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      3.13G     0.8491     0.6645     0.9762         15        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:27<00:00,  3.97s/it]
#                    all        154        249      0.487      0.357      0.403      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      3.13G     0.8518     0.6472     0.9889         11        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:27<00:00,  3.96s/it]
#                    all        154        249      0.812      0.606      0.682       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      3.13G     0.8177     0.6143     0.9785         16        640: 100%|██████████| 57/57 [02:46<00:00,  2.93s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:25<00:00,  3.68s/it]
#                    all        154        249      0.942      0.844       0.92      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      3.13G     0.8061     0.5949      0.974          7        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.08s/it]
#                    all        154        249       0.94      0.775      0.858      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      3.13G     0.7855     0.5645      0.954         14        640: 100%|██████████| 57/57 [02:46<00:00,  2.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:27<00:00,  3.94s/it]
#                    all        154        249      0.925      0.807      0.882      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      3.13G     0.7649     0.5381      0.952          6        640: 100%|██████████| 57/57 [02:45<00:00,  2.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:26<00:00,  3.86s/it]
#                    all        154        249       0.94      0.843       0.92      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      3.13G     0.7649     0.5454     0.9484         10        640: 100%|██████████| 57/57 [02:46<00:00,  2.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.04s/it]
#                    all        154        249      0.951      0.938      0.978      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      3.13G     0.7397     0.5204     0.9441          8        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:29<00:00,  4.15s/it]
#                    all        154        249      0.934      0.912      0.954      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      3.13G     0.7371     0.5108     0.9405         16        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.03s/it]
#                    all        154        249      0.915      0.912      0.954      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      3.13G     0.7171     0.4881     0.9272         15        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.03s/it]
#                    all        154        249       0.98      0.936      0.985      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      3.13G     0.6941     0.4585     0.9253         11        640: 100%|██████████| 57/57 [02:45<00:00,  2.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.03s/it]
#                    all        154        249      0.986      0.968      0.993      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      3.13G     0.6992     0.4686     0.9279          7        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.12s/it]
#                    all        154        249      0.988      0.973       0.99      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      3.13G     0.6953     0.4737     0.9337          7        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:27<00:00,  3.93s/it]
#                    all        154        249      0.971       0.94      0.977      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      3.13G     0.6505      0.434     0.9123         12        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:29<00:00,  4.26s/it]
#                    all        154        249      0.954      0.839      0.949      0.784
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      3.13G     0.5679     0.3638     0.8692          7        640: 100%|██████████| 57/57 [02:46<00:00,  2.93s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:30<00:00,  4.31s/it]
#                    all        154        249      0.974       0.94      0.987      0.833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      3.13G     0.5671     0.3654     0.8699          7        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:25<00:00,  3.65s/it]
#                    all        154        249      0.984      0.971      0.992       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      3.13G     0.5588     0.3498     0.8633          5        640: 100%|██████████| 57/57 [02:47<00:00,  2.93s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:27<00:00,  3.93s/it]
#                    all        154        249      0.975      0.928      0.978      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      3.13G     0.5483     0.3347     0.8596          7        640: 100%|██████████| 57/57 [02:45<00:00,  2.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.11s/it]
#                    all        154        249      0.977      0.924      0.969        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      3.13G     0.5368     0.3302      0.854          3        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.11s/it]
#                    all        154        249      0.961      0.964      0.984      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      3.13G     0.5291     0.3146      0.854          5        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.07s/it]
#                    all        154        249      0.991       0.96       0.99      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      3.13G     0.5157     0.3096     0.8489          6        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.02s/it]
#                    all        154        249      0.983      0.938      0.978      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      3.13G     0.5008     0.2966      0.835          5        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.06s/it]
#                    all        154        249      0.981      0.976      0.994      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      3.13G     0.4916     0.2942       0.84          4        640: 100%|██████████| 57/57 [02:46<00:00,  2.93s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.14s/it]
#                    all        154        249      0.979      0.984      0.994      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      3.13G     0.4933     0.2837     0.8429          9        640: 100%|██████████| 57/57 [02:46<00:00,  2.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:29<00:00,  4.26s/it]
#                    all        154        249      0.987      0.976      0.994      0.874
#
# 30 epochs completed in 2.215 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 22.5MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 22.5MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics YOLOv8.0.42  Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:28<00:00,  4.02s/it]
#                    all        154        249      0.979      0.984      0.994      0.882
# Speed: 0.8ms preprocess, 81.1ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs\detect\train

# %%
model = YOLO(r'runs\detect\train\weights\best.pt')  # load a custom model
predict = model.predict(r"..\TruckDataset\train\images\time3_frame5_003.jpg", save=True, imgsz=640, conf=0.5, show=True)
# Out:
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.42  Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 F:\TruckDetect\Yolov8_Module\TruckDataset\train\images\time3_frame5_003.jpg: 512x640 2 trucks, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict6
